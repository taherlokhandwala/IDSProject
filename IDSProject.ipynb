# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
df = pandas.read_csv('googleplaystore.csv')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Size'] = df['Size'].map(lambda x: x.rstrip('M'))

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Size'] = df['Size'].map(lambda x: str(round((float(x.rstrip('k'))/1024), 1)) if x[-1]=='k' else x)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Size'] = df['Size'].map(lambda x: np.nan if x.startswith('Varies') else x)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Installs'] = df['Installs'].map(lambda x: x.rstrip('+'))

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Installs'] = df['Installs'].map(lambda x: ''.join(x.split(',')))

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Price'] = df['Price'].map(lambda x: x.lstrip('$').rstrip())

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.drop(df.index[10472], inplace=True)

# %%
df.drop(df.index[[7312,8266]], inplace=True)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.sort_values("Category", inplace = True)

# %%
df
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 35                  How to draw Ladybug and Cat Noir  ART_AND_DESIGN     3.8
# 36    UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN     4.7
# 37                                Floor Plan Creator  ART_AND_DESIGN     4.1
# 38                    PIP Camera - PIP Collage Maker  ART_AND_DESIGN     4.7
# ...                                              ...             ...     ...
# 3634                     Free live weather on screen         WEATHER     4.4
# 3633                                    SMHI Weather         WEATHER     3.5
# 3632                      MyRadar NOAA Weather Radar         WEATHER     4.5
# 8168                                   Windguru Lite         WEATHER     4.0
# 3635                            Weather Radar Widget         WEATHER     4.3
#
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer()
df['Rating'] = imputer.fit_transform(df[['Rating']])

df['Rating']=df['Rating'].round(1)

# %%
df['Size'] = imputer.fit_transform(df[['Size']])
df['Size'] = df['Size'].round(1)
df.dropna(axis=0, inplace=True)
df
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 35                  How to draw Ladybug and Cat Noir  ART_AND_DESIGN     3.8
# 36    UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN     4.7
# 37                                Floor Plan Creator  ART_AND_DESIGN     4.1
# 38                    PIP Camera - PIP Collage Maker  ART_AND_DESIGN     4.7
# ...                                              ...             ...     ...
# 3634                     Free live weather on screen         WEATHER     4.4
# 3633                                    SMHI Weather         WEATHER     3.5
# 3632                      MyRadar NOAA Weather Radar         WEATHER     4.5
# 8168                                   Windguru Lite         WEATHER     4.0
# 3635                            Weather Radar Widget         WEATHER     4.3
#
# ...

# %%
df['Reviews'] = pandas.to_numeric(df['Reviews'])
df['Installs'] = pandas.to_numeric(df['Installs'])
df['Price'] = pandas.to_numeric(df['Price'])

# %%
df
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 35                  How to draw Ladybug and Cat Noir  ART_AND_DESIGN     3.8
# 36    UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN     4.7
# 37                                Floor Plan Creator  ART_AND_DESIGN     4.1
# 38                    PIP Camera - PIP Collage Maker  ART_AND_DESIGN     4.7
# ...                                              ...             ...     ...
# 3634                     Free live weather on screen         WEATHER     4.4
# 3633                                    SMHI Weather         WEATHER     3.5
# 3632                      MyRadar NOAA Weather Radar         WEATHER     4.5
# 8168                                   Windguru Lite         WEATHER     4.0
# 3635                            Weather Radar Widget         WEATHER     4.3
#
# ...

# %%
df['Reviews']
# Out:
# 0          159
# 35         564
# 36        8145
# 37       36639
# 38         158
#          ...
# 3634     15370
# 3633     11297
# 3632    178934
# 8168      9307
# 3635     18194
# Name: Reviews, Length: 10827, dtype: int64

# %%
df['Installs']
# Out:
# 0          10000
# 35        100000
# 36        500000
# 37       5000000
# 38         10000
#           ...
# 3634     1000000
# 3633     1000000
# 3632    10000000
# 8168     1000000
# 3635     1000000
# Name: Installs, Length: 10827, dtype: int64

# %%
df['Price']
# Out:
# 0       0.0
# 35      0.0
# 36      0.0
# 37      0.0
# 38      0.0
#        ...
# 3634    0.0
# 3633    0.0
# 3632    0.0
# 8168    0.0
# 3635    0.0
# Name: Price, Length: 10827, dtype: float64

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FAMILY',
#        'FINANCE', 'FOOD_AND_DRINK', 'GAME', 'HEALTH_AND_FITNESS',
#        'HOUSE_AND_HOME', 'LIBRARIES_AND_DEMO', 'LIFESTYLE',
#        'MAPS_AND_NAVIGATION', 'MEDICAL', 'NEWS_AND_MAGAZINES',
#        'PARENTING', 'PERSONALIZATION', 'PHOTOGRAPHY', 'PRODUCTIVITY',
#        'SHOPPING', 'SOCIAL', 'SPORTS', 'TOOLS', 'TRAVEL_AND_LOCAL',
#        'VIDEO_PLAYERS', 'WEATHER'], dtype=object)

# %%
df.Category.value_counts().plot(kind='barh',figsize= (12,8))

# %%
df.Rating.describe()
# Out:
# count    10827.000000
# mean         4.192953
# std          0.479089
# min          1.000000
# 25%          4.100000
# 50%          4.200000
# 75%          4.500000
# max          5.000000
# Name: Rating, dtype: float64

# %%
sns.distplot(df.Rating)

# %%
df.Rating[df['Rating'] == 5 ].count()
# Out:
# 274

# %%
plt.pie(df.Type.value_counts(), labels=['Free', 'Paid'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe272c31fd0>,
# ...
#  [Text(-1.070716264220412, 0.2521243374485791, 'Free'),
#   Text(1.0707162583190157, -0.25212436251050224, 'Paid')],
#  [Text(-0.5840270532111338, 0.13752236588104313, '92.6%'),
#   Text(0.5840270499921904, -0.13752237955118304, '7.4%')])

# %%
df_full = df[df.Rating == 5]

df_full
# Out:
#                                            App             Category  Rating  \
# 8888   Spring flowers theme couleurs d t space       ART_AND_DESIGN     5.0
# 8146                                   CZ-Help  BOOKS_AND_REFERENCE     5.0
# 5966                              BC MVA Fines  BOOKS_AND_REFERENCE     5.0
# 5237                    Hey AJ! It's Saturday!  BOOKS_AND_REFERENCE     5.0
# 5763                Tozer Devotional -Series 1  BOOKS_AND_REFERENCE     5.0
# ...                                        ...                  ...     ...
# 9806                      Dr. ES PV Calculator                TOOLS     5.0
# 8379                                    DG-App                TOOLS     5.0
# 10621              Florida Beach Wallpapers HD     TRAVEL_AND_LOCAL     5.0
# 6171                                  BG Guide     TRAVEL_AND_LOCAL     5.0
# 7435                          CJ's Coffee Cafe     TRAVEL_AND_LOCAL     5.0
#
# ...

# %%
sns.distplot(df_full.Installs)

# %%
sns.distplot(df_full.Reviews)

# %%
newVer = []

for row in df['Android Ver']:
    try:
        newrow = float(row[:2])
    except:
        newrow = 0  # When the value is - Varies with device
    
    newVer.append(newrow)
    
df['Android Ver'] =  newVer

# %%
sns.countplot(df['Android Ver'])  #(●'◡'●)

# %%
trusted=[]

def valcal(x,y):
    if y: 
        return int(x)/int(y)
    else:
        return -1

def removeOutliers(x):
        a = np.array(x)
        upper_quartile = np.percentile(a, 75)
        lower_quartile = np.percentile(a, 25)
        print(upper_quartile,lower_quartile)
        """IQR = (upper_quartile - lower_quartile) * outlierConstant
        outlierRange = 1.5* IQR
        quartileSet = (med - outlierRange, med + outlierRange)"""
        valueList = []
        for y in a.tolist():
            if y >= lower_quartile and y <= upper_quartile:
                valueList.append(y)
            else:
                valueList.append(-1)
        med = np.median(df.trustedApps)
        maxRef = max(upper_quartile - med, med - lower_quartile)
        resultList=[]
        for i in valueList:
            if i!=(-1):
                resultList.append(abs(med-i)/maxRef)
            else:
                resultList.append(-1)
        df['trustedAppsScores']=resultList

df['trustedApps'] = df.apply((lambda x: valcal(x['Reviews'],x['Installs'])), axis=1)
#sns.boxplot(df.trustedApps)
removeOutliers(df.trustedApps)
print(df['trustedAppsScores'])
# Out:
# 0.0392 0.00796
# 0       0.099057
# 35     -1.000000
# 36      0.080660
# 37     -1.000000
# 38      0.103774
#           ...
# 3634    0.124057
# 3633    0.316179
# 3632    0.005028
# 8168    0.410047
# 3635    0.009151
# Name: trustedAppsScores, Length: 10827, dtype: float64

# %%
sns.distplot(df.trustedAppsScores)
df.trustedAppsScores[df['trustedAppsScores']>0].count()
# Out:
# 5381

# %%
df.corr()['Price']
# Out:
# Rating              -0.020144
# Reviews             -0.009676
# Size                -0.023048
# Installs            -0.011700
# Price                1.000000
# Android Ver          0.019181
# trustedApps         -0.048162
# trustedAppsScores   -0.016411
# Name: Price, dtype: float64

# %%
df.corr()['Android Ver']
# Out:
# Rating              -0.024746
# Reviews             -0.122212
# Size                 0.075841
# Installs            -0.185742
# Price                0.019181
# Android Ver          1.000000
# trustedApps          0.001467
# trustedAppsScores   -0.038122
# Name: Android Ver, dtype: float64
